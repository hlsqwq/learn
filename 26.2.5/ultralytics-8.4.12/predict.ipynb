# %%
from ultralytics import YOLO


yolo = YOLO(model='demo.pt',task='detect')
res = yolo(source='1.png', save=True)
# Out:
# image 1/1 C:\python\code\ultralytics-8.4.12\1.png: 416x640 1 trash, 2 computers, 8.7ms
# Speed: 1.4ms preprocess, 8.7ms inference, 0.3ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to C:\python\code\ultralytics-8.4.12\runs\detect\predict7

# %%
print(res[0].names)
print(res[0].boxes.cls)
print(res[0].boxes.xywh)
# Out:
# {0: 'trash', 1: 'computer'}
# tensor([0., 1., 1.], device='cuda:0')
# tensor([[1554.6501,  778.5225,   49.8130,   66.6368],
#         [1550.0129,  929.5803,   68.2440,   63.9744],
#         [1550.0996,  929.1675,   67.2052,   62.6664]], device='cuda:0')

# %%
# Out:
# tensor([[1529.7437,  745.2040, 1579.5566,  811.8408],
#         [1515.8910,  897.5931, 1584.1350,  961.5674],
#         [1516.4969,  897.8343, 1583.7021,  960.5007]], device='cuda:0')
